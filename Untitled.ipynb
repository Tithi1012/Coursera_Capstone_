# %% [markdown]
# <h4> <b> CAPSTONE PROJECT IBM </b> </h4>
# <h1> Jupyter Notebook <h1>
# <hr> <hr>
# <h5> <i> This will be used for the Capstone Project of IBM Data Science </i> (Course 9 of the specialization) <h5>

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
